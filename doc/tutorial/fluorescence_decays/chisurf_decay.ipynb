# %% [markdown]
# # Fluorescence decay analysis in ChiSurf
#
# Development:
# * https://github.com/fluorescence-tools/chisurf
# * https://gitlab.peulen.xyz/chisurf
#
# Various versions:
# https://peulen.xyz/downloads/chisurf/

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# ## TCSPC basics

# %%
YouTubeVideo('qa4UQnhO-8M')

# %% [markdown]
# ## Loading data in ChiSurf

# %%
YouTubeVideo('rtllur-jUag')

# %% [markdown]
# ## FRET sensitized emission

# %%
YouTubeVideo('DDw7LR6GeHA')
